# %% [markdown]
# # **Funcones Con Parametros**

# %% [markdown]
# Alas funciones podemos añadirles parametros para que trabajen con valores ingresados por el usuario

# %%
def adicion (a,b):
  total = a+b
  return total

# %%
print(adicion(1,2))

# %% [markdown]
# Argumentos de tipo Key:Value

# %%
def person_info(name, lastname, carrer):
  print(f'Hola {name} {lastname}, Gracias por escoger la carrera de {carrer}. Comencemos con la seleccion')

# %%
print(person_info,(name))

# %% [markdown]
# Tipos De Valores

# %%
# String
def name (name):
  return name
  neme('Gerardo')

# %%
# Booleanos
def is_pair(n):
  if n%2 == 0:
    return True
    return False
    print(is_pair(8))
    print(is_pair(5))

# %%
# Listas
def find_pair(n):
  pairs = []
  for i in range(n+2):
    if i%2 == 0:
      paird.append(i)
      return pairs
      print(find_pair(10))
